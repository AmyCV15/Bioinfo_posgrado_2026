# %% [markdown]
# <a href="https://colab.research.google.com/github/AmyCV15/Bioinfo_posgrado_2026/blob/master/Mi_primer_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=3

# %% [markdown]
# Esto es una gráfica
